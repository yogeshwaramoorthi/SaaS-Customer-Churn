# %%
import pandas as pd
import numpy as np
import random

# --- 1. GENERATE FAKE SAAS DATA ---
np.random.seed(42) # For reproducible results
n_customers = 1000

data = {
    'Customer_ID': [f'CUST_{i}' for i in range(1000, 2000)],
    'Subscription_Type': np.random.choice(['Basic', 'Pro', 'Enterprise'], n_customers, p=[0.5, 0.3, 0.2]),
    'Monthly_Bill': [],
    'Total_Support_Calls': np.random.poisson(2, n_customers), # Average 2 calls
    'Days_Active': np.random.randint(30, 1000, n_customers),
    'Churned': []
}

# Logic: Higher bills + More support calls = Higher chance of churn
for i in range(n_customers):
    sub = data['Subscription_Type'][i]
    calls = data['Total_Support_Calls'][i]

    # Set Bill based on Plan
    if sub == 'Basic': bill = 29
    elif sub == 'Pro': bill = 99
    else: bill = 299
    data['Monthly_Bill'].append(bill)

    # Calculate Churn Probability
    churn_prob = 0.10 # Base churn
    if calls > 4: churn_prob += 0.40 # Angry customers churn
    if bill == 299: churn_prob -= 0.05 # Enterprise customers usually stay

    # Decide if they churned
    data['Churned'].append(np.random.choice(['Yes', 'No'], p=[churn_prob, 1-churn_prob]))

df = pd.DataFrame(data)

# --- 2. PREVIEW DATA ---
print("✅ Dataset Generated Successfully!")
print(f"Total Rows: {df.shape[0]}")
print(f"Columns: {df.columns.tolist()}")
df.head()
# Out:
# ✅ Dataset Generated Successfully!
# Total Rows: 1000
# Columns: ['Customer_ID', 'Subscription_Type', 'Monthly_Bill', 'Total_Support_Calls', 'Days_Active', 'Churned']
#   Customer_ID Subscription_Type  Monthly_Bill  Total_Support_Calls  \
# 0   CUST_1000             Basic            29                    1
# 1   CUST_1001        Enterprise           299                    6
# 2   CUST_1002               Pro            99                    1
# 3   CUST_1003               Pro            99                    2
# 4   CUST_1004             Basic            29                    2
#
#    Days_Active Churned
# 0          945      No
# 1          884     Yes
# 2          667      No
# 3          616      No
# 4          706      No

# %%
import plotly.express as px

# --- CHART 1: The "Bleeding" Report (Overall Churn) ---
# Goal: Show how many customers we are losing.
fig1 = px.pie(df, names='Churned', title='Overall Churn Rate (How many left?)',
              color='Churned', color_discrete_map={'Yes':'red', 'No':'green'})
fig1.show()

# --- CHART 2: The "Smoking Gun" (Support Calls vs Churn) ---
# Goal: Prove that angry customers (high support calls) are the ones leaving.
fig2 = px.histogram(df, x="Total_Support_Calls", color="Churned", barmode="group",
                    title="Why are they leaving? (Support Calls Analysis)",
                    color_discrete_map={'Yes':'red', 'No':'blue'})
fig2.show()

# --- CHART 3: Revenue Impact ---
# Goal: Are we losing Cheap (Basic) or Expensive (Enterprise) customers?
fig3 = px.box(df, x="Subscription_Type", y="Monthly_Bill", color="Churned",
              title="Churn Distribution by Plan Type",
              color_discrete_map={'Yes':'red', 'No':'blue'})
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5d74b728-70b8-4a4e-add3-eebf53ad6f54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d74b728-70b8-4a4e-add3-eebf53ad6f54")) {                    Plotly.newPlot(                        "5d74b728-70b8-4a4e-add3-eebf53ad6f54",                        [{"customdata":[["No"],
1,3,1,1,2,5,4,2,2,5,1,2,0,0,1,1,1,2,2,3,3,1,1,1,2,3,1,5,2,3,0,3,0,4,1,2,3,1,0,2,2,2,3,1,2,2,1,2,1,1,2,0,4,2,3,1,2,2,0,1,2,0,4,5,0,0,6,0,1,0,3,3,5,5,2,3,6,3,2,1,1,0,2,3,2,0,1,4,3,3,1,1,1,0,1,4,2,1,1,1,2,2,0,2,1,2,0,2,0,3,4,4,3,3,2,0,2,3,1,2,1,1,2,3,2,0,3,2,2,0,4,2,2,1,2,2,0,1,4,0,0,3,0,0,1,2,1,2,3,0,3,1,4,1,1,4,1,3,2,0,2,1,4,3,2,4,2,1,2,2,2,1,0,3,2,2,2,2,1,4,3,0,2,2,3,1,2,0,3,3,2,3,2,4,1,3,2,4,2,1,1,1,0,1,2,3,2,4,3,1,1,4,1,3,2,1,2,1,2,0,2,1,2,3,0,2,1,2,3,2,3,3,3,2,0,2,2,2,3,1,2,0,0,2,3,1,1,4],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churned=Yes\u003cbr\u003eTotal_Support_Calls=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"red","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"x":[6,2,1,5,3,2,3,2,5,6,6,3,1,2,4,2,2,1,2,3,5,2,2,5,5,1,1,3,0,3,6,0,2,1,3,2,5,3,5,1,1,5,2,5,6,4,2,1,1,5,5,1,5,1,3,2,5,6,4,6,3,1,2,2,5,3,6,1,5,2,1,0,5,2,1,6,3,3,2,6,0,0,1,3,2,2,2,1,1,0,5,6,1,3,2,3,4,6,5,4,1,2,2,4,1,2,5,1,1,0,6,1,2,0,0,3,5,2,5,1,0],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b548b223-20d9-4d4c-ae80-a468de5e8f02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b548b223-20d9-4d4c-ae80-a468de5e8f02")) {                    Plotly.newPlot(                        "b548b223-20d9-4d4c-ae80-a468de5e8f02",                        [{"alignmentgroup":"True","hovertemplate":"Churned=No\u003cbr\u003eSubscription_Type=%{x}\u003cbr\u003eMonthly_Bill=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"blue"},"name":"No","notched":false,"offsetgroup":"No","orientation":"v","showlegend":true,"x":["Basic","Pro","Pro","Basic","Basic","Basic","Enterprise","Pro","Basic","Enterprise","Enterprise","Basic","Pro","Basic","Pro","Basic","Basic","Basic","Pro","Basic","Pro","Pro","Pro","Basic","Enterprise","Enterprise","Enterprise","Basic","Pro","Basic","Basic","Basic","Basic","Basic","Pro","Basic","Pro","Basic","Enterprise","Pro","Enterprise","Enterprise","Pro","Enterprise","Basic","Basic","Basic","Basic","Basic","Enterprise","Basic","Pro","Basic","Enterprise","Basic","Enterprise","Pro","Basic","Basic","Enterprise","Pro","Pro","Basic","Basic","Basic","Enterprise","Basic","Basic","Pro","Pro","Enterprise","Basic","Basic","Pro","Pro","Pro","Pro","Pro","Basic","Basic","Basic","Basic","Pro","Basic","Enterprise","Basic","Basic","Pro","Basic","Basic","Basic","Basic","Enterprise","Enterprise","Pro","Enterprise","Enterprise","Basic","Enterprise","Pro","Enterprise","Enterprise","Basic","Basic","Basic","Basic","Enterprise","Enterprise","Basic","Pro","Basic","Basic","Basic","Basic","Enterprise","Basic","Pro","Pro","Basic","Enterprise","Enterprise","Basic","Basic","Basic","Pro","Pro","Enterprise","Basic","Basic","Enterprise","Basic","Pro","Pro","Basic","Pro","Basic","Pro","Pro","Basic","Enterprise","Basic","Basic","Basic","Pro","Basic","Pro","Basic","Pro","Basic","Pro","Basic","Enterprise","Basic","Basic","Basic","Enterprise","Enterprise","Basic","Pro","Enterprise","Pro","Basic","Basic","Enterprise","Enterprise","Pro","Basic","Basic","Pro","Enterprise","Enterprise","Pro","Pro","Basic","Basic","Enterprise","Pro","Basic","Pro","Basic","Pro","Pro","Basic","Pro","Basic","Basic","Pro","Pro","Enterprise","Pro","Pro","Basic","Basic","Enterprise","Basic","Enterprise","Pro","Pro","Pro","Basic","Basic","Pro","Basic","Basic","Pro","Basic","Enterprise","Enterprise","Enterprise","Basic","Basic","Enterprise","Basic","Enterprise","Enterprise","Enterprise","Basic","Enterprise","Basic","Enterprise","Pro","Pro","Basic","Pro","Enterprise","Basic","Pro","Enterprise","Pro","Pro","Basic","Basic","Enterprise","Enterprise","Enterprise","Enterprise","Pro","Pro","Pro","Pro","Pro","Pro","Enterprise","Basic","Basic","Pro","Basic","Basic","Pro","Basic","Pro","Basic","Basic","Enterprise","Basic","Basic","Pro","Pro","Basic","Pro","Basic","Basic","Pro","Pro","Pro","Pro","Enterprise","Pro","Basic","Pro","Basic","Basic","Basic","Basic","Enterprise","Enterprise","Pro","Basic","Basic","Basic","Basic","Pro","Pro","Pro","Basic","Enterprise","Pro","Pro","Pro","Basic","Basic","Basic","Pro","Basic","Basic","Basic","Basic","Enterprise","Pro","Basic","Basic","Basic","Basic","Basic","Pro","Pro","Basic","Basic","Pro","Pro","Enterprise","Pro","Basic","Basic","Pro","Basic","Pro","Enterprise","Pro","Basic","Pro","Basic","Enterprise","Enterprise","Basic","Basic","Basic","Basic","Basic","Basic","Enterprise","Basic","Enterprise","Basic","Basic","Pro","Pro","Enterprise","Pro","Enterprise","Basic","Basic","Pro","Enterprise","Enterprise","Basic","Basic","Pro","Basic","Enterprise","Enterprise","Basic","Pro","Basic","Basic","Enterprise","Basic","Basic","Enterprise","Basic","Enterprise","Enterprise","Pro","Basic","Basic","Pro","Pro","Pro","Pro","Basic","Bas ...

# %% [markdown]
# # 📊 Business Insights & Recommendations
#
# ### 1. The "Support" Problem
# * **Observation:** Customers who call support **more than 5 times** have a near 100% churn rate.
# * **Hypothesis:** These customers are frustrated with unresolved technical issues.
#
# ### 2. Pricing Strategy
# * **Observation:** Enterprise customers ($299/mo) churn significantly *less* than Basic customers ($29/mo).
# * **Action:** The sales team should focus on upselling Basic users to Enterprise plans to increase retention.
#
# ### 3. Immediate Recommendation
# * **Alert System:** Flag any customer who makes their **4th support call**. Send a Senior Agent to resolve their issue immediately to prevent churn.
